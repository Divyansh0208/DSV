# %%
import numpy as np
import pandas as pd

# %%
student_df=pd.DataFrame({
    "Name": ["prabhav", "pranav", "chirag", "divyansh"],
    "Age": [19, 20, 18, 21],
    "City": ["gorakhpur", "patna", "delhi", "lucknow"]
})

# %%
student_df
# Out:
#        Name  Age       City
# 0   prabhav   19  gorakhpur
# 1    pranav   20      patna
# 2    chirag   18      delhi
# 3  divyansh   21    lucknow

# %%
student_df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
student_df["Name"]
# Out:
# 0     prabhav
# 1      pranav
# 2      chirag
# 3    divyansh
# Name: Name, dtype: object

# %%
student_df["City"]
# Out:
# 0    gorakhpur
# 1        patna
# 2        delhi
# 3      lucknow
# Name: City, dtype: object

# %%
name_city_df=student_df[["Name", "City"]]
name_city_df
# Out:
#        Name       City
# 0   prabhav  gorakhpur
# 1    pranav      patna
# 2    chirag      delhi
# 3  divyansh    lucknow

# %%
book_df=pd.DataFrame({
    "Book": ["NLP with Pyton", "Machine Learning", "LLM"],
    "Author": ["Steven Bird", "Aurélien Géron", "Maarten Grootendorst"],
    "Price": [450, 600, 750]
})

# %%
book_df["Publisher"]="O’Reilly"
book_df
# Out:
#                Book                Author  Price Publisher
# 0    NLP with Pyton           Steven Bird    450  O’Reilly
# 1  Machine Learning        Aurélien Géron    600  O’Reilly
# 2               LLM  Maarten Grootendorst    750  O’Reilly

# %%
ser_df=pd.DataFrame({
    "Item": ["pen", "pencil", "dairy", "copy", "book"]
})

# %%
ser_df["SerialNo"]=np.arange(5)
ser_df
# Out:
#      Item  SerialNo
# 0     pen         0
# 1  pencil         1
# 2   dairy         2
# 3    copy         3
# 4    book         4

# %%
ser_df.drop(columns=["SerialNo"], inplace=True)
ser_df
# Out:
#      Item
# 0     pen
# 1  pencil
# 2   dairy
# 3    copy
# 4    book

# %%
movie_df=pd.DataFrame({
    "Movie": ["Inception", "Interstellar", "Jumanji"],
    "Year": [2010, 2014, 2017],
    "Rating": [8.8, 8.7, 7.9]
})
movie_df
# Out:
#           Movie  Year  Rating
# 0     Inception  2010     8.8
# 1  Interstellar  2014     8.7
# 2       Jumanji  2017     7.9

# %%
movie_new_df=movie_df.reindex(columns=["Movie", "Rating", "Director"])
movie_new_df
# Out:
#           Movie  Rating  Director
# 0     Inception     8.8       NaN
# 1  Interstellar     8.7       NaN
# 2       Jumanji     7.9       NaN

# %%
city_df=pd.Series(["Lucknow", "Mathura"],index=[0, 3])
city_df
# Out:
# 0    Lucknow
# 3    Mathura
# dtype: object

# %%
branch_df=pd.DataFrame({"Student": ["prabhav", "pranav", "chirag", "divyansh"]})
branch_df["branch"]=city_df
branch_df
# Out:
#     Student   branch
# 0   prabhav  Lucknow
# 1    pranav      NaN
# 2    chirag      NaN
# 3  divyansh  Mathura

# %%
employee_df=pd.DataFrame({
    "Employee": ["prabhav", "abhishek", "pranav", "chirag", "divyansh"],
    "Department": ["IT", "HR", "Finance", "Marketing", "IT"],
    "Experience": [2, 4, 1, 3, 5]
})

# %%
experience_df=employee_df[["Employee", "Experience"]]
experience_df
# Out:
#    Employee  Experience
# 0   prabhav           2
# 1  abhishek           4
# 2    pranav           1
# 3    chirag           3
# 4  divyansh           5

# %%
employee_df["Department"]
employee_df.columns
# Out:
# Index(['Employee', 'Department', 'Experience'], dtype='object')

# %%
employee_df["Office"]="Head Office"
employee_df
# Out:
#    Employee Department  Experience       Office
# 0   prabhav         IT           2  Head Office
# 1  abhishek         HR           4  Head Office
# 2    pranav    Finance           1  Head Office
# 3    chirag  Marketing           3  Head Office
# 4  divyansh         IT           5  Head Office

# %%
employee_df["Office"]=np.arange(5)
employee_df
# Out:
#    Employee Department  Experience  Office
# 0   prabhav         IT           2       0
# 1  abhishek         HR           4       1
# 2    pranav    Finance           1       2
# 3    chirag  Marketing           3       3
# 4  divyansh         IT           5       4

# %%
office=pd.Series(["lucknow", "mathura", "delhi"], index=[0, 2, 4])
employee_df=office
employee_df
# Out:
# 0    lucknow
# 2    mathura
# 4      delhi
# dtype: object

# %%
employee_df.drop(columns=["office"], inplace=True)
employee_df
# Out:
# 0    lucknow
# 2    mathura
# 4      delhi
# dtype: object

# %%
product_df=pd.DataFrame({
    "Product": ["Laptop", "Mouse", "Keyboard"],
    "Category": ["Electronics", "Accessories", "Accessories"],
    "Price": [155000, 1000, 2000]
})
ordered_df=product_df[["Price","Product","Category"]]
ordered_df
# Out:
#     Price   Product     Category
# 0  155000    Laptop  Electronics
# 1    1000     Mouse  Accessories
# 2    2000  Keyboard  Accessories

# %%
result = product_df.reindex(columns=["Product", "Category", "Price", "Brand"])
result
# Out:
#     Product     Category   Price  Brand
# 0    Laptop  Electronics  155000    NaN
# 1     Mouse  Accessories    1000    NaN
# 2  Keyboard  Accessories    2000    NaN

# %%
marks_df = pd.DataFrame({
    "Student": ["Aman", "Riya", "Karan"],
    "Total Marks": [85, 92, 78]
})
marks_df["Total Marks"]
# Out:
# 0    85
# 1    92
# 2    78
# Name: Total Marks, dtype: int64

# %%
course_df = pd.DataFrame({
    "Student": ["Aman", "Riya", "Karan", "Neha", "Vikram"],
    "Course": ["Python", "Java", "Python", "SQL", "C++"],
    "Score": [85, 92, 78, 88, 95]
})
course_df.columns
# Out:
# Index(['Student', 'Course', 'Score'], dtype='object')

# %%
course_df["Student"]
# Out:
# 0      Aman
# 1      Riya
# 2     Karan
# 3      Neha
# 4    Vikram
# Name: Student, dtype: object

# %%
student_score = course_df[["Student", "Score"]]
student_score
# Out:
#   Student  Score
# 0    Aman     85
# 1    Riya     92
# 2   Karan     78
# 3    Neha     88
# 4  Vikram     95

# %%
course_df["Batch"] = "2026"
course_df
# Out:
#   Student  Course  Score Batch
# 0    Aman  Python     85  2026
# 1    Riya    Java     92  2026
# 2   Karan  Python     78  2026
# 3    Neha     SQL     88  2026
# 4  Vikram     C++     95  2026

# %%
travel_df = pd.DataFrame({
    "place": ["Delhi", "Mathura", "Agra", "Jaipur", "Lucknow"],
    "distance": [200, 1400, 230, 280, 1800],
    "vehicle": ["Car", "Train", "Bus", "Car", "Flight"],
    "price": [3000, 5000, 2000, 3500, 8000],
    "days": [2, 5, 2, 3, 6]
})
travel_df["Code"] = np.arange(5)
travel_df
# Out:
#      place  distance vehicle  price  days  Code
# 0    Delhi       200     Car   3000     2     0
# 1  Mathura      1400   Train   5000     5     1
# 2     Agra       230     Bus   2000     2     2
# 3   Jaipur       280     Car   3500     3     3
# 4  Lucknow      1800  Flight   8000     6     4

# %%
code = pd.Series(
    ["x", "y"],
    index=[1, 4],
    name="Code"
)
travel_df["Code"] = code
travel_df
# Out:
#      place  distance vehicle  price  days Code
# 0    Delhi       200     Car   3000     2  NaN
# 1  Mathura      1400   Train   5000     5    x
# 2     Agra       230     Bus   2000     2  NaN
# 3   Jaipur       280     Car   3500     3  NaN
# 4  Lucknow      1800  Flight   8000     6    y

# %%
school_df = pd.DataFrame({
    "Student": ["Aman", "Riya", "Karan"],
    "Class": [4, 5, 6],
    "Section": ["A", "B", "c"]
})
new = school_df.reindex( columns=["Student", "Class", "Section", "House"])
new
# Out:
#   Student  Class Section  House
# 0    Aman      4       A    NaN
# 1    Riya      5       B    NaN
# 2   Karan      6       c    NaN

# %%
new["House"] = "Red"
new
# Out:
#   Student  Class Section House
# 0    Aman      4       A   Red
# 1    Riya      5       B   Red
# 2   Karan      6       c   Red

# %%
inventory_df=pd.DataFrame({
    "Product": ["laptop", "mouse", "keyboard"],
    "Category": ["electronics", "accessories", "accessories"],
    "Price": [155000, 1000, 2000]
})

stock_series = pd.Series(
    [5, 12],
    index=[0, 2],
    name= "restock"
)

inventory_df["restock"] = stock_series
inventory_df
# Out:
#     Product     Category   Price  restock
# 0    laptop  electronics  155000      5.0
# 1     mouse  accessories    1000      NaN
# 2  keyboard  accessories    2000     12.0

# %%
del inventory_df["restock"]
inventory_df
# Out:
#     Product     Category   Price
# 0    laptop  electronics  155000
# 1     mouse  accessories    1000
# 2  keyboard  accessories    2000
